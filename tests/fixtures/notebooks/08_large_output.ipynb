# %%
for i in range(1000):
    print(f'line {i:04d}')
# Out:
# line 0000 — данные
# line 0001 — данные
# line 0002 — данные
# line 0003 — данные
# line 0004 — данные
# line 0005 — данные
# line 0006 — данные
# line 0007 — данные
# line 0008 — данные
# line 0009 — данные
# line 0010 — данные
# line 0011 — данные
# line 0012 — данные
# line 0013 — данные
# line 0014 — данные
# line 0015 — данные
# line 0016 — данные
# line 0017 — данные
# line 0018 — данные
# line 0019 — данные
# line 0020 — данные
# line 0021 — данные
# line 0022 — данные
# line 0023 — данные
# line 0024 — данные
# line 0025 — данные
# line 0026 — данные
# line 0027 — данные
# line 0028 — данные
# line 0029 — данные
# line 0030 — данные
# line 0031 — данные
# line 0032 — данные
# line 0033 — данные
# line 0034 — данные
# line 0035 — данные
# line 0036 — данные
# line 0037 — данные
# line 0038 — данные
# line 0039 — данные
# line 0040 — данные
# line 0041 — данные
# line 0042 — данные
# line 0043 — данные
# line 0044 — данные
# line 0045 — данные
# line 0046 — данные
# ...

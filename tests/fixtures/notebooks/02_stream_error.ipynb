# %%
print('first')
print('second')
# Out:
# first
# second
# warning

# %%
raise ValueError('boom')
# Out:
# ---------------------------------------------------------------------------
# ValueError: boom

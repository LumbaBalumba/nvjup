# %% [markdown]
# # Анализ данных 📊
#
# Markdown with **bold**, $x^2$, and an attachment.
#
# ![pixel](attachment:pixel.png)

# %%
import numpy as np
values = np.array([1, 2, 3])

# %%
values.mean()
# Out:
# 2.0

# %% [raw]
# This raw cell must be preserved verbatim.
